# %% [markdown]
# # Reading API Documentation
#
# ## Introduction
# We've now covered an example API request, but how on Earth would you know how to do that on your own? The answer is through documentation! All APIs will have associated documentation, and while there are substantial similarities, all will be different to one degree or another. The best way to get more comfortable is to practice! So with that, let's take a look at the yelp documentation associated with our previous example.
#
# ## Objectives
#
# You will be able to:
#
# * Interpret API documentation into Python code
# * Make requests using OAuth
#
# Start by navigating to https://www.yelp.com/developers/documentation/v3/get_started and having a look for yourself!
#
# <img src="images/yelp_overview.png" width="800">
#
# As you see at the top, the first piece of almost every API is authentication.
#
# This is where we started in the previous codealong, where we went to https://www.yelp.com/developers/v3/manage_app and created a new app.
#
# <img src="images/yelp_app.png"  width="800">

# %% [markdown]
# Let's take a closer look at Yelp's authentication documentation:
# https://www.yelp.com/developers/documentation/v3/authentication
#
# <img src="images/yelp_auth.png" width="800">

# %% [markdown]
# Notice in the documentation, it gives us the specific format "Put the API Key in the request header as "Authorization: Bearer <YOUR API KEY>"." This is what we passed in our get request.
#
#
# Before we do this, let's import your authentication token which you have appropriately stored in **a separate file** from the codealong before.

# %%
import json

#Our previous function for loading our api key file
def get_keys(path):
    with open(path) as f:
        return json.load(f)

# %% [markdown]
# > **Note**: Like before, change the file path below to be your root directory.
# If you're not sure what your username is, check it with `pwd`
# For example, my current working directory is ```/Users/matthew.mitchell/Documents/dsc-using-yelp-api-codealong```
# So the line below would become:
# ```keys = get_keys("/Users/matthew.mitchell/.secret/yelp_api.json")```

# %%
keys = get_keys("C://Users//user//.secret//yelp_api.json")

api_key = keys['api_key']

#While you may wish to print out these api keys to check that they imported properly,
#be sure to clear the output before uploading to Github. 
#Again, you don't want your keys stolen!!!

# %%
import requests

# %%
url = #This will be our next step
header = {"Authorization" : "Bearer {}".format(api_key)}
response = requests.get(url, header=header)
# Out:
#   File "<ipython-input-5-99271e4af878>", line 1
#     url = #This will be our next step
#           ^
# SyntaxError: invalid syntax

# %% [markdown]
#  With that, let's take a look at how the rest of our request should be formatted. Go to https://www.yelp.com/developers/documentation/v3/business_search  and take a couple of minutes to look things over.
#
#  <img src="images/yelp_docs.png"  width="800">

# %% [markdown]
# Notice the first part is the format of the get request! This is the URL we pass into our get request. From there, the available parameters that you can pass are listed. These define your query, some are required while others are optional.
#
# Reviewing our python package we thus have:

# %%
url = 'https://api.yelp.com/v3/businesses/search'

headers = {
        'Authorization': 'Bearer {}'.format(api_key),
    }

url_params = {
                'location': 'NYC'
            }
response = requests.get(url, headers=headers, params=url_params)
response.text
# Out:
# '{"businesses": [{"id": "nRO136GRieGtxz18uD61DA", "alias": "eleven-madison-park-new-york", "name": "Eleven Madison Park", "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/s_H7gm_Hwmz--O6bo1iU-A/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/eleven-madison-park-new-york?adjust_creative=qSi3RrNgkwYp-m509fWqtQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=qSi3RrNgkwYp-m509fWqtQ", "review_count": 2416, "categories": [{"alias": "newamerican", "title": "American (New)"}, {"alias": "french", "title": "French"}, {"alias": "cocktailbars", "title": "Cocktail Bars"}], "rating": 4.5, "coordinates": {"latitude": 40.7416907417333, "longitude": -73.9872074872255}, "transactions": [], "price": "$$$$", "location": {"address1": "11 Madison Ave", "address2": "", "address3": "", "city": "New York", "zip_code": "10010", "country": "US", "state": "NY", "display_address": ["11 Madison Ave", "New York, NY 10010"]}, "phone": "+12128890905", "display_phone": "(212) 889-0905", "distance": 3892.073000575764}, {"id": "veq1Bl1DW3UWMekZJUsG1Q", "alias": "gramercy-tavern-new-york", "name": "Gramercy Tavern", "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/f14WAmWETi0cu2f6rUBj-Q/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/gramercy-tavern-new-york?adjust_creative=qSi3RrNgkwYp-m509fWqtQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=qSi3RrNgkwYp-m509fWqtQ", "review_count": 3352, "categories": [{"alias": "newamerican", "title": "American (New)"}], "rating": 4.5, "coordinates": {"latitude": 40.73844, "longitude": -73.98825}, "transactions": ["delivery"], "price": "$$$$", "location": {"address1": "42 E 20th St", "address2": "", "address3": "", "city": "New York", "zip_code": "10003", "country": "US", "state": "NY", "display_address": ["42 E 20th St", "New York, NY 10003"]}, "phone": "+12124770777", "display_phone": "(212) 477-0777", "distance": 3563.6380884303935}, {"id": "h37t9rA06Sr4EetJjKrfzw", "alias": "don-angie-new-york", "name": "Don Angie", "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/onJX6_vaMPHXUqIbMrq79A/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/don-angie-new-york?adjust_creative=qSi3RrNgkwYp-m509fWqtQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=qSi3RrNgkwYp-m509fWqtQ", "review_count": 734, "categories": [{"alias": "italian", "title": "Italian"}, {"alias": "newamerican", "title": "American (New)"}], "rating": 4.5, "coordinates": {"latitude": 40.73778, "longitude": -74.00197}, "transactions": ["delivery"], "price": "$$$", "location": {"address1": "103 Greenwich Ave", "address2": "", "address3": null, "city": "New York", "zip_code": "10014", "country": "US", "state": "NY", "display_address": ["103 Greenwich Ave", "New York, NY 10014"]}, "phone": "+12128898884", "display_phone": "(212) 889-8884", "distance": 3916.353269127091}, {"id": "s3jou_L_LVYGkNHiuhjlew", "alias": "boucherie-west-village-new-york-3", "name": "Boucherie West Village", "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/WxNMDkguiN5eVOOA9WEaog/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/boucherie-west-village-new-york-3?adjust_creative=qSi3RrNgkwYp-m509fWqtQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=qSi3RrNgkwYp-m509fWqtQ", "review_count": 2241, "categories": [{"alias": "french", "title": "French"}, {"alias": "cocktailbars", "title": "Cocktail Bars"}, {"alias": "steak", "title": "Steakhouses"}], "rating": 4.5, "coordinates": {"latitude": 40.733063, "longitude": -74.0028772}, "transactions": ["delivery", "pickup"], "price": "$$$", "location": {"address1": "99 7th Ave S", "address2": "", "address3": null, "city": "New York", "zip_code": "10014", "country": "US", "state": "NY", "display_address": ["99 7th Ave S", "New York, NY 10014"]}, "phone": "+12128371616", "display_phone": "(212) 837-1616", "distance": 3508.6398355906513}, {"id": "ehUuSk5gPTCQmwS_ubgKRA", "alias": "upstate-craft-beer-and-oyster-bar- ...

# %% [markdown]
# Note that location or latitude and longitude are the only required parameters. That said, you are free to pass as many parameters as you want such as:

# %%
url = 'https://api.yelp.com/v3/businesses/search'

headers = {
        'Authorization': 'Bearer {}'.format(api_key),
    }

url_params = {
                'location': 'NYC',
                'term' : 'pizza',
                'limit' : 50,
                'price' : "1,2,3,4",
                'open_now' : True
            }
response = requests.get(url, headers=headers, params=url_params)
response.text
# Out:
# '{"businesses": [{"id": "VP3-iMnKK_TaHDuy6mxTzA", "alias": "scotts-pizza-tours-new-york", "name": "Scott\'s Pizza Tours", "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/nhfA9SXPjeX9H4KfjTcn9w/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/scotts-pizza-tours-new-york?adjust_creative=qSi3RrNgkwYp-m509fWqtQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=qSi3RrNgkwYp-m509fWqtQ", "review_count": 371, "categories": [{"alias": "pizza", "title": "Pizza"}, {"alias": "foodtours", "title": "Food Tours"}, {"alias": "walkingtours", "title": "Walking Tours"}], "rating": 5.0, "coordinates": {"latitude": 40.750244140625, "longitude": -73.9970245361328}, "transactions": [], "price": "$$", "location": {"address1": "", "address2": "", "address3": "", "city": "New York", "zip_code": "10001", "country": "US", "state": "NY", "display_address": ["New York, NY 10001"]}, "phone": "", "display_phone": "", "distance": 5459.62038134444}, {"id": "1G8aL9TFGZPSr6GooLRQkg", "alias": "k-pizza-palisades-park", "name": "K Pizza", "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/lYNzmJ21h6GWYW7kHAQxYQ/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/k-pizza-palisades-park?adjust_creative=qSi3RrNgkwYp-m509fWqtQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=qSi3RrNgkwYp-m509fWqtQ", "review_count": 68, "categories": [{"alias": "pizza", "title": "Pizza"}], "rating": 3.5, "coordinates": {"latitude": 40.842018, "longitude": -74.000809}, "transactions": ["delivery"], "price": "$$", "location": {"address1": "26 E Columbia Ave", "address2": "", "address3": "", "city": "Palisades Park", "zip_code": "07650", "country": "US", "state": "NJ", "display_address": ["26 E Columbia Ave", "Palisades Park, NJ 07650"]}, "phone": "+12013130079", "display_phone": "(201) 313-0079", "distance": 15125.758452607673}, {"id": "MpF9j5-fBH0H6L9AzzyArA", "alias": "little-italy-pizza-new-york-25", "name": "Little Italy Pizza", "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/PVDO55__StArkCjy2mb_gA/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/little-italy-pizza-new-york-25?adjust_creative=qSi3RrNgkwYp-m509fWqtQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=qSi3RrNgkwYp-m509fWqtQ", "review_count": 181, "categories": [{"alias": "pizza", "title": "Pizza"}], "rating": 3.5, "coordinates": {"latitude": 40.7081041823001, "longitude": -74.0046897976739}, "transactions": ["pickup", "delivery"], "price": "$", "location": {"address1": "50 Fulton St", "address2": "", "address3": "", "city": "New York", "zip_code": "10038", "country": "US", "state": "NY", "display_address": ["50 Fulton St", "New York, NY 10038"]}, "phone": "+12125717700", "display_phone": "(212) 571-7700", "distance": 2153.3029238219992}, {"id": "HLvLgKNWjrTVvlK4iyZ9Vg", "alias": "famous-original-rays-pizza-new-york-14", "name": "Famous Original Ray\'s Pizza", "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/5IH3UvgrF89d_FoejbIdsg/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/famous-original-rays-pizza-new-york-14?adjust_creative=qSi3RrNgkwYp-m509fWqtQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=qSi3RrNgkwYp-m509fWqtQ", "review_count": 446, "categories": [{"alias": "italian", "title": "Italian"}, {"alias": "pizza", "title": "Pizza"}], "rating": 2.5, "coordinates": {"latitude": 40.7632745057344, "longitude": -73.9815969765186}, "transactions": ["pickup", "delivery"], "price": "$", "location": {"address1": "831 7th Ave", "address2": "", "address3": "", "city": "New York", "zip_code": "10019", "country": "US", "state": "NY", "display_address": ["831 7th Ave", "New York, NY 10019"]}, "phone": "+12129749381", "display_phone": "(212) 974-9381", "distance": 6622.177936658203}, {"id": "vjubSxmdG_HoBBgd39geBw", "alias": "ninos-46-new-york", "name": "Nino\'s 46", "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/wFy83D_d5e89zMGcO5omWg/o.jpg", "is_closed": false, "url": "https ...

# %% [markdown]
# The final important note is how some of the parameters have alternative formats. For example, `limit` is an integer and `open_now` is a boolean according to the documentation. Following these conventions is essential to receiving valid responses.
#
# # Summary
#
# Congratulations! Not only have you seen an API now, you've also practiced sifting through the documentation. The last piece in working with APIs is developing a more solid understanding of JSON files; the data format typically returned by modern APIs. Take some additional time and familiarize yourself with some further aspects of the documentation which you may wish to investigate in the upcoming lab!
